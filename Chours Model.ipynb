# %%
import pandas as pd
dataset = pd.read_csv('Data/Final Data.csv')
print(dataset.shape)
dataset.head()
# Out:
# (751, 523)
#            Artist                           Title  Label  \
# 0      The Weeknd                 Blinding Lights      1
# 1  Olivia Rodrigo                        Good 4 U      1
# 2  Olivia Rodrigo                 Drivers License      1
# 3       Lil Nas X  Montero (Call Me By Your Name)      1
# 4             BTS                          Butter      1
#
#                                                 Path  \
# 0  Songs/The Weeknd - Blinding Lights (Official V...
# 1  Songs/Olivia Rodrigo - good 4 u (Official Vide...
# 2  Songs/Olivia Rodrigo - drivers license (Offici...
# 3  Songs/Lil Nas X - MONTERO (Call Me By Your Nam...
# 4         Songs/BTS (방탄소년단) 'Butter' Official MV.mp3
#
#                                           choruspath  chroma_stft_kew_0  \
# 0  Songs/RepeatedPopularChorus/The Weeknd - Blind...           0.091806
# 1  Songs/RepeatedPopularChorus/Olivia Rodrigo - g...           1.025965
# 2  Songs/RepeatedPopularChorus/Olivia Rodrigo - d...           1.395750
# 3  Songs/RepeatedPopularChorus/Lil Nas X - MONTER...           0.926616
# 4  Songs/RepeatedPopularChorus/BTS (방탄소년단) 'Butte...           0.311976
#
#    chroma_stft_min_0  chroma_stft_max_0  chroma_stft_std_0  \
# 0           0.049545                1.0           0.306971
# 1           0.007265                1.0           0.274179
# 2           0.000648                1.0           0.307888
# 3           0.003467                1.0           0.242382
# 4           0.037900                1.0           0.336300
#
#    chroma_stft_mean_0  ...  tonnetz_mean_5  tonnetz_median_5  \
# 0            0.570429  ...        0.007217         -0.000351
# 1            0.350277  ...       -0.011851         -0.010293
# 2            0.236975  ...        0.001545         -0.009260
# 3            0.301311  ...       -0.014834         -0.023444
# 4            0.517165  ...        0.005743          0.005232
#
#    tonnetz_kurtosis_5  zero_crossing_rate_kew_0  zero_crossing_rate_min_0  \
# 0           -0.410349                 -0.604349                  0.022585
# 1            0.099909                 -0.233246                  0.057460
# 2            0.360879                  0.742759                  0.023492
# 3            0.456362                  0.524002                  0.051111
# 4           -0.153372                  2.700198                  0.046848
#
#    zero_crossing_rate_max_0  zero_crossing_rate_std_0  \
# 0                  0.102132                  0.017701
# 1                  0.229705                  0.035304
# 2                  0.178957                  0.032571
# 3                  0.277596                  0.045581
# 4                  0.235737                  0.030815
#
#    zero_crossing_rate_mean_0  zero_crossing_rate_median_0  \
# 0                   0.072071                     0.074626
# 1                   0.147578                     0.157302
# 2                   0.077563                     0.066463
# 3                   0.147997                     0.142472
# 4                   0.097298                     0.090204
#
#    zero_crossing_rate_kurtosis_0
# 0                       0.012681
# 1                      -0.281870
# 2                      -0.180427
# 3                      -0.344706
# 4                       7.939578
#
# [5 rows x 523 columns]

# %% [markdown]
# ### Drop unnecessary columns which are dataset['Path'] and dataset['chourspath']

# %%
dataset = dataset.drop('Path', axis=1).drop('choruspath', axis=1)
dataset.head()
# Out:
#            Artist                           Title  Label  chroma_stft_kew_0  \
# 0      The Weeknd                 Blinding Lights      1           0.091806
# 1  Olivia Rodrigo                        Good 4 U      1           1.025965
# 2  Olivia Rodrigo                 Drivers License      1           1.395750
# 3       Lil Nas X  Montero (Call Me By Your Name)      1           0.926616
# 4             BTS                          Butter      1           0.311976
#
#    chroma_stft_min_0  chroma_stft_max_0  chroma_stft_std_0  \
# 0           0.049545                1.0           0.306971
# 1           0.007265                1.0           0.274179
# 2           0.000648                1.0           0.307888
# 3           0.003467                1.0           0.242382
# 4           0.037900                1.0           0.336300
#
#    chroma_stft_mean_0  chroma_stft_median_0  chroma_stft_kurtosis_0  ...  \
# 0            0.570429              0.556123               -1.389693  ...
# 1            0.350277              0.265414                0.140231  ...
# 2            0.236975              0.087020                0.739644  ...
# 3            0.301311              0.262466                0.285644  ...
# 4            0.517165              0.438171               -1.429111  ...
#
#    tonnetz_mean_5  tonnetz_median_5  tonnetz_kurtosis_5  \
# 0        0.007217         -0.000351           -0.410349
# 1       -0.011851         -0.010293            0.099909
# 2        0.001545         -0.009260            0.360879
# 3       -0.014834         -0.023444            0.456362
# 4        0.005743          0.005232           -0.153372
#
#    zero_crossing_rate_kew_0  zero_crossing_rate_min_0  \
# 0                 -0.604349                  0.022585
# 1                 -0.233246                  0.057460
# 2                  0.742759                  0.023492
# 3                  0.524002                  0.051111
# 4                  2.700198                  0.046848
#
#    zero_crossing_rate_max_0  zero_crossing_rate_std_0  \
# 0                  0.102132                  0.017701
# 1                  0.229705                  0.035304
# 2                  0.178957                  0.032571
# 3                  0.277596                  0.045581
# 4                  0.235737                  0.030815
#
#    zero_crossing_rate_mean_0  zero_crossing_rate_median_0  \
# 0                   0.072071                     0.074626
# 1                   0.147578                     0.157302
# 2                   0.077563                     0.066463
# 3                   0.147997                     0.142472
# 4                   0.097298                     0.090204
#
#    zero_crossing_rate_kurtosis_0
# 0                       0.012681
# 1                      -0.281870
# 2                      -0.180427
# 3                      -0.344706
# 4                       7.939578
#
# [5 rows x 521 columns]

# %% [markdown]
# ### Figure 1. Pair plot of the median value of all major audio features

# %%
import seaborn as sns

columns = dataset.columns
median_columns = ['Label']
for column in columns:
    if column .count('median_0') > 0:
        median_columns.append(column)

sns.pairplot(dataset[median_columns], hue='Label')

# %% [markdown]
# ### Plot explained variance & Make biplot with the number of features with pca library.

# %%
from pca import pca

X = dataset.drop('Artist', axis=1).drop('Title',axis=1).drop('Label', axis=1)

# Initialize to reduce the data up to the nubmer of componentes that explains 95% of the variance.
model = pca(normalize=True)

# Fit transform
out = model.fit_transform(X)

# Plot explained variance
fig, ax = model.plot(n_components=400)

# Make biplot with the number of features
fig, ax = model.biplot(y=dataset['Label'], n_feat=5)
# Out:
# [pca] >Processing dataframe..
# [pca] >Normalizing input data per feature (zero mean and unit variance)..
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [518] columns of the input data.
# [pca] >Fitting using PCA..
# [pca] >Computing loadings and PCs..
# [pca] >Computing explained variance..
# [pca] >Number of components is [170] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [518] columns of the input dataframe.
# [pca] >Fitting using PCA..
# [pca] >Computing loadings and PCs..
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[170]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
# [pca] >Plot PC1 vs PC2 with loadings.

# %% [markdown]
# ### Find best feature which we will use & these features which reach variance to 95% .

# %%
# print(out['topfeat'])

df = pd.DataFrame(out['topfeat'])
df[df['type']=='best']
# Out:
#         PC                   feature   loading  type
# 0      PC1  spectral_contrast_mean_1  0.100396  best
# 1      PC2         chroma_stft_kew_3 -0.104222  best
# 2      PC3   spectral_centroid_max_0 -0.104029  best
# 3      PC4            tonnetz_mean_0 -0.185015  best
# 4      PC5            tonnetz_mean_1 -0.201033  best
# ..     ...                       ...       ...   ...
# 165  PC166   spectral_contrast_min_5  0.195870  best
# 166  PC167     chroma_cqt_kurtosis_4  0.161224  best
# 167  PC168   spectral_contrast_min_3 -0.251567  best
# 168  PC169         chroma_cqt_max_11 -0.167807  best
# 169  PC170           mfcc_kurtosis_5 -0.174138  best
#
# [170 rows x 4 columns]

# %% [markdown]
# ### Take X and y variables to training the model

# %%
columns = list(df['feature'][df['type']=='best'])
X = dataset[columns]
y = dataset['Label']

# %% [markdown]
# ### Split the into X_train, X_test, y_train, y_test with test_size=0.2 and train_size=0.8

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2022)

# %% [markdown]
# ### Build two methods:
# - `First:- metrics:` to store metrics for all models.
# - `Second:- training ` to train al models.

# %%
import warnings
warnings.filterwarnings('ignore')
# from mlxtend.evaluate import bias_variance_decomp
from sklearn.metrics import f1_score, precision_score, recall_score, plot_confusion_matrix

dic = []

def metrics(name, model, X_train, y_train, X_test, y_test, y_pred):
    dic.append({
        'name': name,
        'train acc': model.score(X_train, y_train),
        'test acc': model.score(X_test, y_test),

        'f1 train acc': f1_score(y_train, model.predict(X_train)),
        'f1 test acc': f1_score(y_test, y_pred),

        'precision train acc': precision_score(y_train, model.predict(X_train)),
        'precision test acc': precision_score(y_test, y_pred),

        'recall train acc': recall_score(y_train, model.predict(X_train)),
        'recall test acc': recall_score(y_test, y_pred)
    })

def training(model, X_train, y_train, X_test, y_test, name):
    clf = model.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    # mse, bias, var = bias_variance_decomp(model, X_train.values, y_train.values, X_test.values, y_test.values, loss='mse', num_rounds=200, random_seed=random)

    metrics(name, clf, X_train, y_train, X_test, y_test, y_pred)

    return clf

# %% [markdown]
# ### Build ML models which are
# - SVC(kernel='linear')         (linearSVC_model)
# - SVC(kernel='poly')           (polySVC_model)
# - SVC(kernel='rbf')            (rbfSVC_model)
# - LogisticRegression           (log_model)
# - RandomForestClassifier       (rfc_model)
# - GradientBoostingClassifier   (gbm_model)
# - LinearDiscriminantAnalysis   (lda_model)

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

log_model = training(LogisticRegression(max_iter=1000), X_train, y_train, X_test, y_test, 'LR')
linearSVC_model = training(SVC(kernel='linear'), X_train, y_train, X_test, y_test, 'Linear SVM')
polySVC_model = training(SVC(kernel='poly'), X_train, y_train, X_test, y_test, 'Poly SVM')
rbfSVC_model = training(SVC(kernel='rbf'), X_train, y_train, X_test, y_test, 'Rbf SVM')
rfc_model = training(RandomForestClassifier(), X_train, y_train, X_test, y_test, 'RFC')
gbm_model = training(GradientBoostingClassifier(), X_train, y_train, X_test, y_test, 'GBM')
lda_model = training(LinearDiscriminantAnalysis(), X_train, y_train, X_test, y_test, 'LDA')

# %% [markdown]
# ### Convert metrixs into DataFrame

# %%
df = pd.DataFrame(dic)
df
# Out:
#          name  train acc  test acc  f1 train acc  f1 test acc  \
# 0          LR   0.645000  0.496689      0.630849     0.464789
# 1  Linear SVM   0.638333  0.483444      0.631579     0.472973
# 2    Poly SVM   0.511667  0.549669      0.300716     0.358491
# 3     Rbf SVM   0.505000  0.523179      0.139130     0.121951
# 4         RFC   1.000000  0.496689      1.000000     0.415385
# 5         GBM   1.000000  0.437086      1.000000     0.397163
# 6         LDA   0.703333  0.443709      0.693103     0.440000
#
#    precision train acc  precision test acc  recall train acc  recall test acc
# 0             0.645390            0.464789          0.616949         0.464789
# 1             0.632653            0.454545          0.630508         0.492958
# 2             0.508065            0.542857          0.213559         0.267606
# 3             0.480000            0.454545          0.081356         0.070423
# 4             1.000000            0.457627          1.000000         0.380282
# 5             1.000000            0.400000          1.000000         0.394366
# 6             0.705263            0.417722          0.681356         0.464789

# %% [markdown]
# ### See different between `train acc`, `test acc` in train and validation.

# %%
df.plot(x = 'name', y = ['train acc', 'test acc'], kind = 'bar')
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
# ### See different between `f1 train acc`, `f1 test acc` in train and validation.

# %%
df.plot(x = 'name', y = ['f1 train acc', 'f1 test acc'], kind = 'bar')
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
# ### See different between `precision train acc`, `precision test acc` in train and validation.

# %%
df.plot(x = 'name', y = ['precision train acc', 'precision test acc'], kind = 'bar')
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
# ### See different between `recall train acc`, `recall test acc` in train and validation.

# %%
df.plot(x = 'name', y = ['recall train acc', 'recall test acc'], kind = 'bar')
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
# ### Save all models

# %%
import pickle

pickle.dump(log_model, open('Models/log_model.pkl', 'wb'))
pickle.dump(lda_model, open('Models/lda_model.pkl', 'wb'))
pickle.dump(linearSVC_model, open('Models/linearSVC_model.pkl', 'wb'))
pickle.dump(polySVC_model, open('Models/polySVC_model.pkl', 'wb'))
pickle.dump(rbfSVC_model, open('Models/rbfSVC_model.pkl', 'wb'))
pickle.dump(rfc_model, open('Models/rfc_model.pkl', 'wb'))
pickle.dump(gbm_model, open('Models/gbm_model.pkl', 'wb'))
